# %% [markdown]
# # Итоговый проект по автобрее
# ### Выполнили:
# - Аксенова Анна
# - Волошина Екатерина
# - Кудрявцева Полина
# - Такташева Екатерина

# %% [markdown]
# ## Этап 2: поисковые запросы
#
# Поиск оформлен в класс <code>Corpus</code>. Поиск осуществляется при помощи метода <code>Corpus.search()</code>.
#
# Всего в классе есть 5 вида поиска:
# - <code>Corpus.search('"pattern"')</code> - поиск по точному вхождению (поддерживает униграммы, биграммы и триграммы)
# - <code>Corpus.search('word+POS')</code> - ищет все вхождения слова *word* с частью речи *POS* (поддерживает униграммы, биграммы и триграммы)<code>
# - <code>Corpus.search('word')</code> - ищет вхождение слова *word* в любой из форм
# - <code>Corpus.search('POS')</code> - поиск по частям речи (работает с униграммами, биграммами и триграммами: <code>Corpus.pos_search('POS POS POS')</code> )
# - <code>Corpus.search('POS word')</code> - находит все предложения, где встречается сочетание *POS* + *word* в любой форме (также поддерживает униграммы, биграммы и триграммы и т. д.)

# %%
# !wget -O "corpora_data.csv" "https://docs.google.com/uc?export=download&id=1U0EmC9E782eQfzmR9slB5-_b5dsvFhuC"
# Out:
# --2020-10-23 00:03:22--  https://docs.google.com/uc?export=download&id=1U0EmC9E782eQfzmR9slB5-_b5dsvFhuC
# Распознаётся docs.google.com (docs.google.com)… 2a00:1450:4010:c08::c2, 74.125.205.194
# Подключение к docs.google.com (docs.google.com)|2a00:1450:4010:c08::c2|:443... соединение установлено.
# HTTP-запрос отправлен. Ожидание ответа… 302 Moved Temporarily
# Адрес: https://doc-04-4g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/rf29u4uikunu39q1m2op6qco2r4a3onj/1603400550000/13218383390176395157/*/1U0EmC9E782eQfzmR9slB5-_b5dsvFhuC?e=download [переход]
# Предупреждение: в HTTP маски не поддерживаются.
# --2020-10-23 00:03:24--  https://doc-04-4g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/rf29u4uikunu39q1m2op6qco2r4a3onj/1603400550000/13218383390176395157/*/1U0EmC9E782eQfzmR9slB5-_b5dsvFhuC?e=download
# Распознаётся doc-04-4g-docs.googleusercontent.com (doc-04-4g-docs.googleusercontent.com)… 2a00:1450:4026:804::2001, 216.58.209.161
# Подключение к doc-04-4g-docs.googleusercontent.com (doc-04-4g-docs.googleusercontent.com)|2a00:1450:4026:804::2001|:443... соединение установлено.
# HTTP-запрос отправлен. Ожидание ответа… 200 OK
# Длина: нет данных [text/csv]
# Сохранение в: «corpora_data.csv»
#
# corpora_data.csv        [       <=>          ]  33,44M   729KB/s    за 3m 0s
#
# 2020-10-23 00:06:25 (190 KB/s) - «corpora_data.csv» сохранён [35060758]

# %%
import pandas as pd
import numpy as np
import os

 
data = pd.read_csv('corpora_data.csv', delimiter='\t', encoding='utf-8')

# %%
data
# Out:
#                                                   source               title  \
# 0      https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%...  Материальная точка
# 1      https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%...  Материальная точка
# 2      https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%...  Материальная точка
# 3      https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%...  Материальная точка
# 4      https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%...  Материальная точка
# ...                                                  ...                 ...
# 36827  https://ru.wikipedia.org/wiki/1556%20%D0%B3%D0...            1556 год
# 36828  https://ru.wikipedia.org/wiki/1556%20%D0%B3%D0...            1556 год
# 36829  https://ru.wikipedia.org/wiki/1556%20%D0%B3%D0...            1556 год
# 36830  https://ru.wikipedia.org/wiki/1556%20%D0%B3%D0...            1556 год
# 36831  https://ru.wikipedia.org/wiki/1556%20%D0%B3%D0...            1556 год
#
#                                                 sentence  \
# 0      Материальная точка (частица)  — обладающее мас...
# 1      Является простейшей физической моделью в механ...
# 2      Положение материальной точки в пространстве оп...
# 3      В классической механике масса материальной точ...
# 4      Материальная точка — геометрическая точка, кот...
# ...                                                  ...
# 36827  Антоний Сийский — преподобный Русской церкви, ...
# 36828  Физули — Классик азербайджанской поэзии, сыгра...
# 36829  Писал на азербайджанском, персидском и арабско...
# 36830  Хумаюн — второй из Великих Моголов, сын Бабура...
# 36831  Максим Грек — православный святой, переводчик ...
#
#                                                tokenized  \
# 0      Материальная точка частица — обладающее массой...
# 1      Является простейшей физической моделью в механике
# 2      Положение материальной точки в пространстве оп...
# 3      В классической механике масса материальной точ...
# 4      Материальная точка — геометрическая точка кото...
# ...                                                  ...
# 36827  Антоний Сийский — преподобный Русской церкви о...
# 36828  Физули — Классик азербайджанской поэзии сыграв...
# 36829  Писал на азербайджанском персидском и арабском...
# 36830  Хумаюн — второй из Великих Моголов сын Бабура ...
# 36831  Максим Грек — православный святой переводчик и...
#
#                                               lemmatized  \
# 0      материальный точка частица — обладать масса те...
# 1      являться простой физический модель в|в механик...
# 2      положение материальный точка в|в пространство ...
# 3      в|в классический механика|механик масса матери...
# 4      материальный точка — геометрический точка кото...
# ...                                                  ...
# 36827  антоний|антония сийский — преподобный русский ...
# 36828  физули — классик|классика азербайджанский поэз...
# 36829  писать на|на|на азербайджанский персидский и|и...
# 36830  хумаюна — втора|второй иза|из великое|великий ...
# 36831  максима|максим грек — православный святой пере...
#
#                                                      pos
# 0      ADJ NOUN NOUN UNK PTCP NOUN NOUN NOUN NOUN NOU...
# 1                  VERB ADJ ADJ NOUN NOUN|PREP NOUN|NOUN
# 2      NOUN ADJ NOUN NOUN|PREP NOUN VERB PART|CONJ|AD...
# 3      NOUN|PREP ADJ NOUN|NOUN NOUN ADJ NOUN VERB ADJ...
# 4      ADJ NOUN UNK ADJ NOUN ADJ PTCP NOUN|PREP NOUN ...
# ...                                                  ...
# 36827  NOUN|NOUN ADJ UNK ADJ ADJ NOUN NOUN INTJ|NOUN|...
# 36828  NOUN UNK NOUN|NOUN ADJ NOUN PTCP ADJ NOUN|NOUN...
# 36829  VERB INTJ|PREP|PART ADJ ADJ INTJ|NOUN|PART|CON...
# 36830  NOUN UNK NOUN|ADJ NOUN|PREP NOUN|ADJ NOUN NOUN...
# 36831  NOUN|NOUN NOUN UNK ADJ ADJ NOUN INTJ|NOUN|PART...
#
# [36832 rows x 6 columns]

# %%
import re
from tqdm import tqdm

# %%
class Corpus():
    def __init__(self, data):
        self.data = data
    
    
    def simple_search(self, pattern, ntop=10, complex_s=False):
        """
        search by exact wordforms / patterns
        """
 
        pattern = pattern.strip('"')
        
        answers = []
        indeces = []
 
        for sent_ind, sent in data.iterrows():
            if pattern in sent['sentence'].split():
                word_ind = sent['sentence'].split().index(pattern)
                changed_sent = re.sub(r'(\b|^)' + pattern + r'(\b|$)',
                                       '\033[0;34;47m' + pattern + '\033[0m',
                                       sent['sentence'])
                indeces.append((sent_ind, word_ind, sent['sentence'], False))
                answers.append((pattern,
                                sent['source'],
                                sent['title'],
                                changed_sent))
        if complex_s == True:
            return indeces
        else:
            return answers
        
    
    def morph_search(self, pattern, ntop=10, complex_s=False):
        """
        input: pattern ('word+POS')
        
        output: должна вернуть спискок кортежей (pattern, source, title, sentence)
        найденный паттерн выделяется цветом
        в конце печать ответов через self.print_answer(pattern, answers, ntop)
        """
        answers = []
        indeces = []
 
        lemma, pos_tag = pattern.split('+')
        for sent_ind, sent in self.data.iterrows():
            if lemma in sent['lemmatized']: # есть ли в предложении
                lemmas = sent['lemmatized'].split() 
                pos = sent['pos'].split()
                for word_ind, one in enumerate(lemmas): # идем по номерам лемм
                    if lemma in one.split('|') and pos_tag in pos[word_ind].split('|'):
                        token = sent['tokenized'].split()[word_ind]
                        changed_sent = re.sub(r'(\b|^)' + token + r'(\b|$)', 
                                       '\033[0;34;47m' + token + '\033[0m', 
                                       sent['sentence'])
                        indeces.append((sent_ind, word_ind, sent['sentence'], False))
                        answers.append((pattern, 
                                        sent['source'], 
                                        sent['title'], 
                                        changed_sent))
        if complex_s == True:
            return indeces
        else:
            return answers    
    
    
    def form_search(self, pattern, ntop=10, complex_s=False):
        """
        input: pattern ('word')
        
        output: должна вернуть спискок кортежей (pattern, source, title, sentence)
        найденный паттерн выделяется цветом
        в конце печать ответов через self.print_answer(pattern, answers, ntop)
        """
        answers = []
        indeces = []
 
        for sent_ind, sent in self.data.iterrows():
            if pattern in sent['lemmatized']:
                for word_ind in range(len(sent['lemmatized'].split())):
                    if pattern in sent['lemmatized'].split()[word_ind].split('|'):
                        changed_sent = re.sub(r'(\b|^)' + sent['tokenized'].split()[word_ind] + r'(\b|$)', 
                                       '\033[0;34;47m' + sent['tokenized'].split()[word_ind] + '\033[0m', 
                                       sent['sentence'])
                        indeces.append((sent_ind, word_ind, sent['sentence'], False))
                        answers.append((pattern, 
                                sent['source'], 
                                sent['title'], 
                                changed_sent))
                    
        if complex_s == True:
            return indeces
        else:
            return answers
    
    
    def pos_search(self, pattern, ntop=10, complex_s=False):
        """
        input: pattern ('POS')
        
        output: должна вернуть спискок кортежей (pattern, source, title, sentence)
        найденный паттерн выделяется цветом
        в конце печать ответов через self.print_answer(pattern, answers, ntop)
        """
        
        answers = []
        indeces = []
 
        for sent_ind, sent in self.data.iterrows():
            if pattern in sent['pos']:
                for word_ind in range(len(sent['pos'].split())):
                    if pattern in sent['pos'].split()[word_ind].split('|'):
                        changed_sent = re.sub(r'(\b|^)' + sent['tokenized'].split()[word_ind] + r'(\b|$)', 
                                       '\033[0;34;47m' + sent['tokenized'].split()[word_ind] + '\033[0m', 
                                       sent['sentence'])
                        indeces.append((sent_ind, word_ind, sent['sentence'], False))
                        answers.append((pattern, 
                                sent['source'], 
                                sent['title'], 
                                changed_sent))
        if complex_s == True:
            return indeces
        else:
            return answers

    def analyze(self, pattern, column, indeces):
        """
        pattern(str) - паттерн поиска (например, NOUN  или "поиска")
        column(str) - название нужного столбца в датафрейме
        indeces(list) - список кортежей (индекс предложения, индекс слова)

        Функция проверяет, соответствует ли слово, 
        следующее за уже найденным паттерну запроса
        """
        
        new_indeces = []
        answers = []
        
        for sent_id, first_word_id, sentence, changed in indeces: # индекс предложения, индекс слова в предложении
            
            answer = self.data[column][sent_id].split() # строка, по которой ведется поиск
            word_id = first_word_id + 1
            if word_id < len(answer) and answer[word_id] == '—':
                word_id += 1  # индекс слова, которое мы ищем
            if word_id < len(answer) and answer[word_id] == pattern: # соответсвует ли слово паттерну

                if not changed:
                    sentence = sentence.split()
                    sentence[first_word_id] = '\033[0;34;47m' + sentence[first_word_id] + '\033[0m'  # делаем выделение первого слова паттерна
                    sentence = ' '.join(sentence)

                changed_sent = sentence.split()
                changed_sent[word_id] = '\033[0;34;47m' + changed_sent[word_id] + '\033[0m'  # делаем выделение последующего слова
                changed_sent = ' '.join(changed_sent)
              
                new_indeces.append((sent_id, word_id, changed_sent, True)) # добавляет индекс предложения и индекс слова, которое нашли
                answers.append((pattern, # паттерн
                                data['source'][sent_id], # источник
                                data['title'][sent_id], # название статьи
                                changed_sent)) # форматирование выдачи (когда в индексах будут предложения, ЗАМЕНИТ)Ь
        return new_indeces, answers
 
 
 
    def check_next_word(self, pattern, indeces, is_last=False):
        """
        pattern(str) - паттерн поиска (например, NOUN  или "поиска")
        index(list) - список кортежей (индекс предложения, индекс слова)
        is_last(bool) - True, если последнее слово в запросе, 
                      False - в остальных случаях
        """
        answers = [] 
        new_indeces = []
        
        continue_simple_search = False # проверяет, продолжается ли поиск по токенам
     
        if '+' in pattern: # поиск знать+NOUN, поиск одновременно по леммам и частям речи, поэтому не вызывает analyze()
            for sent_id, old_id, sentence, changed in indeces:
                word, pos_tag = pattern.split('+')
                answer = self.data['lemmatized'][sent_id].split()
                pos = self.data['pos'][sent_id].split()
                word_id = old_id + 1
                if word_id < len(answer) and answer[word_id] == 'UNK':
                    word_id += 1
                if word_id < len(answer) and word in answer[word_id].split('|') and pos_tag in pos[word_id].split('|'):
                  
                    if not changed:
                        sentence = sentence.split()
                        sentence[old_id] = '\033[0;34;47m' + sentence[old_id] + '\033[0m'  # делаем выделение первого слова паттерна
                        sentence = ' '.join(sentence)
                  
                    changed_sent = sentence.split()
                    changed_sent[word_id] = '\033[0;34;47m' + changed_sent[word_id] + '\033[0m'  # делаем выделение последующего слова
                    changed_sent = ' '.join(changed_sent)

                    new_indeces.append((sent_id, word_id, changed_sent, True))
                    answers.append((pattern,
                                     data['source'][sent_id], 
                                     data['title'][sent_id],
                                     changed_sent))
                                 
        elif '"' in pattern: # поиск по токену
            if not pattern.endswith('"'):
                continue_simple_search = True # продолжает поиск, если слово не заканчивается кавычкой
            pattern = pattern.strip('"')
            new_indeces, answers = self.analyze(pattern, 'tokenized', indeces)
                    
        elif pattern.isupper(): # поиск по части речи
            new_indeces, answers = self.analyze(pattern, 'pos', indeces)

        else: # поиск по лемме
            new_indeces, answers = self.analyze(pattern, 'lemmatized', indeces)
 
        if is_last == False: # если не последнее слово, то возвращает индексы предложений и слов
            return new_indeces, continue_simple_search
        else: # если последнее, то возвращает ответы в заданном формате
            return answers
    
    
    def search(self, pattern, ntop=10):
        """
        input: pattern ('POS word POS') и любые вариации 
        + мб можно добавить и возможность смешанного поиска: чтобы можно было найти
        что-то типа 'POS word+POS word', но немного сложновато кажется
        
        output: должна вернуть спискок кортежей (pattern, source, title, sentence)
        найденный паттерн выделяется цветом
        в конце печать ответов через self.print_answer(pattern, answers, ntop)
        """
 
        print(f'Поиск по запросу: {pattern}\n')
 
        pattern = pattern.split()
        if len(pattern) == 1:
            complex_s = False
        else:
            complex_s = True
        
        # поиск предложения с первым словом в запросе
        if '"' in pattern[0]:
            answers = self.simple_search(pattern[0], ntop, complex_s)
            if not pattern[0].endswith('"'):
                pattern[1] = '"' + pattern[1]
        elif '+' in pattern[0]:
            answers = self.morph_search(pattern[0], ntop, complex_s)           
        elif pattern[0].isupper():
            answers = self.pos_search(pattern[0], ntop, complex_s)
        else:
            answers = self.form_search(pattern[0], ntop, complex_s)
            
  
        for i in range(1, len(pattern)):
            if i != len(pattern) - 1:
                answers, continue_simple_search = self.check_next_word(pattern[i], answers, is_last=False)
                if continue_simple_search == True:
                    pattern[i+1] = '"' + pattern[i+1]
            else:
                answers = self.check_next_word(pattern[i], answers, is_last=True)
        
        self.print_answer(pattern, answers, ntop)
      
    def write_file(self, pattern, answers):
        """
        writes file with search results
        """
        
        i = 1
        PATH = 'search_results_{}.csv'.format(i)
        while os.path.exists(PATH):
            i += 1
            PATH = 'search_results_{}.csv'.format(i)
        else:
            df = pd.DataFrame(answers, columns=['pattern', 'source', 'title', 'sentence'])
            df.to_csv(PATH, sep='\t')
            
    
    def print_answer(self, pattern, answers, ntop):
        """
        print the answer
        if the output is too big, asks the user to write a file
        with seacrh results
        """
        
        if ntop > len(answers):
            ntop = len(answers)
            
        print(f'\nРЕЗУЛЬТАТЫ ({ntop}/{len(answers)}):\n')
        
        for sent in answers[:ntop]:
            print(f'Источник: {sent[2]} ({sent[1]})')  # sent[2] это название статьи,  sent[1] - ссылка на нее
            print(sent[3]+'\n')  # sent[3] - это само предложение
        
        if len(answers) > 10:
            more = input('Показать больше примеров? (y/n) ')
        
            if more == 'y':
                n = answers[ntop:]
                if len(n) >= 10:
                    more = input('Примеров слишком много для вывода. Записать примеры в файл? (y/n) ')
                    if more == 'y':
                        self.write_file(pattern, answers)
                        print('Файл удачно записан.')
                else:
                    for sent in answers[ntop:]:
                        print(f'\nИсточник: {sent[2]} ({sent[1]})')
                        print(sent[3]+'\n')

# %%
corpus = Corpus(data)

# %%
corpus.search('"идти в одном"')
# Out:
# Поиск по запросу: "идти в одном"
#
#
# РЕЗУЛЬТАТЫ (1/1):
#
# Источник: Сирота, Михаил Дмитриевич (https://ru.wikipedia.org/wiki/%D0%A1%D0%B8%D1%80%D0%BE%D1%82%D0%B0%2C%20%D0%9C%D0%B8%D1%85%D0%B0%D0%B8%D0%BB%20%D0%94%D0%BC%D0%B8%D1%82%D1%80%D0%B8%D0%B5%D0%B2%D0%B8%D1%87)
# Когда нет объединяющей идеи, невозможно сгруппироваться и идти в одном направлении.

# %%
corpus.search('VERB "огонь"')
# Out:
# Поиск по запросу: VERB "огонь"
#
#
# РЕЗУЛЬТАТЫ (3/3):
#
# Источник: Зороастризм (https://ru.wikipedia.org/wiki/%D0%97%D0%BE%D1%80%D0%BE%D0%B0%D1%81%D1%82%D1%80%D0%B8%D0%B7%D0%BC)
# Другим символом зороастризма является огонь и аташдан — огненный переносной (в виде сосуда) или стационарный (в виде платформы) алтарь.
#
# Источник: Зороастризм (https://ru.wikipedia.org/wiki/%D0%97%D0%BE%D1%80%D0%BE%D0%B0%D1%81%D1%82%D1%80%D0%B8%D0%B7%D0%BC)
# Огонь дадгах открыт для публичного доступа, помещение, где находится огонь, служит местом собрания общины.
#
# Источник: Эмпедокл (https://ru.wikipedia.org/wiki/%D0%AD%D0%BC%D0%BF%D0%B5%D0%B4%D0%BE%D0%BA%D0%BB)
# Этими корнями являются огонь, воздух, вода и земля.

# %%
corpus.search('"является" федеративный NOUN')
# Out:
# Поиск по запросу: "является" федеративный NOUN
#
#
# РЕЗУЛЬТАТЫ (2/2):
#
# Источник: Субъекты Российской Федерации (https://ru.wikipedia.org/wiki/%D0%A1%D1%83%D0%B1%D1%8A%D0%B5%D0%BA%D1%82%D1%8B%20%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%BE%D0%B9%20%D0%A4%D0%B5%D0%B4%D0%B5%D1%80%D0%B0%D1%86%D0%B8%D0%B8)
# Согласно Конституции России, Российская Федерация является федеративным государством и состоит из 85 равноправных субъектов — республик, краёв, областей, городов федерального значения, автономных округов и автономной области.
#
# Источник: Австрия (https://ru.wikipedia.org/wiki/%D0%90%D0%B2%D1%81%D1%82%D1%80%D0%B8%D1%8F)
# Австрия является федеративным государством, объединяющим девять самостоятельных земель.

# %%
corpus.search('механика+NOUN')
# Out:
# Поиск по запросу: механика+NOUN
#
#
# РЕЗУЛЬТАТЫ (10/39):
#
# Источник: Материальная точка (https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%82%D0%B5%D1%80%D0%B8%D0%B0%D0%BB%D1%8C%D0%BD%D0%B0%D1%8F%20%D1%82%D0%BE%D1%87%D0%BA%D0%B0)
# Является простейшей физической моделью в механике.
#
# Источник: Материальная точка (https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%82%D0%B5%D1%80%D0%B8%D0%B0%D0%BB%D1%8C%D0%BD%D0%B0%D1%8F%20%D1%82%D0%BE%D1%87%D0%BA%D0%B0)
# В классической механике масса материальной точки полагается постоянной во времени и не зависящей от каких-либо особенностей её движения и взаимодействия с другими телами.
#
# Источник: Гелий (https://ru.wikipedia.org/wiki/%D0%93%D0%B5%D0%BB%D0%B8%D0%B9)
# В гелии-3 сверхтекучесть возникает лишь при температурах ниже 0.0026 К. Сверхтекучий гелий относится к классу так называемых квантовых жидкостей, макроскопическое поведение которых может быть описано только с помощью квантовой механики.
#
# Источник: Динамика (физика) (https://ru.wikipedia.org/wiki/%D0%94%D0%B8%D0%BD%D0%B0%D0%BC%D0%B8%D0%BA%D0%B0%20%28%D1%84%D0%B8%D0%B7%D0%B8%D0%BA%D0%B0%29)
# В классической механике этими причинами являются силы.
#
# Источник: Динамика (физика) (https://ru.wikipedia.org/wiki/%D0%94%D0%B8%D0%BD%D0%B0%D0%BC%D0%B8%D0%BA%D0%B0%20%28%D1%84%D0%B8%D0%B7%D0%B8%D0%BA%D0%B0%29)
# Также динамикой нередко называют, применительно к другим областям физики (например, к теории поля), ту часть рассматриваемой теории, которая более или менее прямо аналогична динамике в механике, противопоставляясь обычно кинематике (к кинематике в таких теориях обычно относят, например, соотношения, получающиеся из преобразований величин при смене системы отсчёта).
#
# Источник: Динамика (физика) (https://ru.wikipedia.org/wiki/%D0%94%D0%B8%D0%BD%D0%B0%D0%BC%D0%B8%D0%BA%D0%B0%20%28%D1%84%D0%B8%D0%B7%D0%B8%D0%BA%D0%B0%29)
# В результате применения методов динамики к изучению движения конкретных объектов возник ряд специальных дисциплин: небесная механика, баллистика, динамика корабля, самолёта и т. п.
#
# Источник: Динамика (физика) (https://ru.wikipedia.org/wiki/%D0%94%D0%B8%D0%BD%D0%B0%D0%BC%D0%B8%D0%BA%D0%B0%20%28%D1%84%D0%B8%D0%B7%D0%B8%D0%BA%D0%B0%29)
# В классической (ньютоновской) механике масса материальной точки полагается постоянной во времени и независящей от каких-либо особенностей её движения и взаимодействия с другими телами.
#
# Источник: Абсолютно упругое тело (https://ru.wikipedia.org/wiki/%D0%90%D0%B1%D1%81%D0%BE%D0%BB%D1%8E%D1%82%D0%BD%D0%BE%20%D1%83%D0%BF%D1%80%D1%83%D0%B3%D0%BE%D0%B5%20%D1%82%D0%B5%D0%BB%D0%BE)
# Абсолютно упругое тело в механике — частный случай деформируемого тела, которое после прекращения действия причины, вызвавшей его деформацию, полностью восстанавливает исходные размеры и форму, то есть в нём отсутствует остаточная деформация.
#
# Источник: Астрометрия (https://ru.wikipedia.org/wiki/%D0%90%D1%81%D1%82%D1%80%D0%BE%D0%BC%D0%B5%D1%82%D1%80%D0%B8%D1%8F)
# Таким образом, астрометрия является одним из важнейших разделов астрономии, дающим экспериментальную информацию, необходимую для развития остальных разделов (астрофизики, космологии, космогонии, небесной механики, и т. п.).
#
# Источник: Астрометрия (https://ru.wikipedia.org/wiki/%D0%90%D1%81%D1%82%D1%80%D0%BE%D0%BC%D0%B5%D1%82%D1%80%D0%B8%D1%8F)
# На основе этих эмпирических законов Исаак Ньютон описал закон всемирного тяготения и заложил основы классической механики, что привело к появлению научного подхода.
#
# Показать больше примеров? (y/n) n

# %%
corpus.search('красивый+ADJ')
# Out:
# Поиск по запросу: красивый+ADJ
#
#
# РЕЗУЛЬТАТЫ (10/17):
#
# Источник: Швеция (https://ru.wikipedia.org/wiki/%D0%A8%D0%B2%D0%B5%D1%86%D0%B8%D1%8F)
# С 1920-х годов, когда в Стокгольме был впервые проведён конкурс на самую красивую Люсию города, установилась соответствующая традиция, и теперь Люсию ежегодно избирают не только в каждом городе или посёлке, но и в каждой школе.
#
# Источник: Зимний дворец (https://ru.wikipedia.org/wiki/%D0%97%D0%B8%D0%BC%D0%BD%D0%B8%D0%B9%20%D0%B4%D0%B2%D0%BE%D1%80%D0%B5%D1%86)
# Зимний дворец и Дворцовая площадь образуют красивейший архитектурный ансамбль современного города и являются одним из главных объектов внутрироссийского и международного туризма.
#
# Источник: Нижний Новгород (https://ru.wikipedia.org/wiki/%D0%9D%D0%B8%D0%B6%D0%BD%D0%B8%D0%B9%20%D0%9D%D0%BE%D0%B2%D0%B3%D0%BE%D1%80%D0%BE%D0%B4)
# На ней собрано большое количество красивых домов XIX века.
#
# Источник: Мифология (https://ru.wikipedia.org/wiki/%D0%9C%D0%B8%D1%84%D0%BE%D0%BB%D0%BE%D0%B3%D0%B8%D1%8F)
# С созвездием Пса, Льва, Лебедя, Орла, Скорпиона, Рыб связаны красивые легенды.
#
# Источник: Нуаре, Филипп (https://ru.wikipedia.org/wiki/%D0%9D%D1%83%D0%B0%D1%80%D0%B5%2C%20%D0%A4%D0%B8%D0%BB%D0%B8%D0%BF%D0%BF)
# С удовольствием пел в хоре и выступал в любительских спектаклях учебного театра, где и обнаружил свой очень красивый голос, напевая в хоре Цикады, в детском хоре (La manécanterie des Petits Chanteurs à la croix de bois), с которым он пел в католическом соборе Святого Петра в Риме в Пасху в 1949 году и записал свой первый диск в качестве певца под управлением французского композитора Франсуа Веркана (François Vercken).
#
# Источник: Лондон (https://ru.wikipedia.org/wiki/%D0%9B%D0%BE%D0%BD%D0%B4%D0%BE%D0%BD)
# Практической пользы от смены караула, конечно, нет, но эта традиция — одна из самых красивых в Лондоне.
#
# Источник: Мой дядя Бенжамен (https://ru.wikipedia.org/wiki/%D0%9C%D0%BE%D0%B9%20%D0%B4%D1%8F%D0%B4%D1%8F%20%D0%91%D0%B5%D0%BD%D0%B6%D0%B0%D0%BC%D0%B5%D0%BD)
# Клод Жад красива и аппетитна, как и полагалось девушкам в ту славную эпоху.
#
# Источник: Бордоская жидкость (https://ru.wikipedia.org/wiki/%D0%91%D0%BE%D1%80%D0%B4%D0%BE%D1%81%D0%BA%D0%B0%D1%8F%20%D0%B6%D0%B8%D0%B4%D0%BA%D0%BE%D1%81%D1%82%D1%8C)
# Получается жидкость красиво ярко-голубого (небесного) цвета.
#
# Источник: Хром (https://ru.wikipedia.org/wiki/%D0%A5%D1%80%D0%BE%D0%BC)
# Используется в качестве износоустойчивых и красивых гальванических покрытий (хромирование).
#
# Источник: Китай (https://ru.wikipedia.org/wiki/%D0%9A%D0%B8%D1%82%D0%B0%D0%B9)
# Красивые обряды и праздники привлекают зарубежных гостей.
#
# Показать больше примеров? (y/n) n

# %%
corpus.search('красивый+ADJ NOUN')
# Out:
# Поиск по запросу: красивый+ADJ NOUN
#
#
# РЕЗУЛЬТАТЫ (7/7):
#
# Источник: Швеция (https://ru.wikipedia.org/wiki/%D0%A8%D0%B2%D0%B5%D1%86%D0%B8%D1%8F)
# С 1920-х годов, когда в Стокгольме был впервые проведён конкурс на самую красивую Люсию города, установилась соответствующая традиция, и теперь Люсию ежегодно избирают не только в каждом городе или посёлке, но и в каждой школе.
#
# Источник: Нижний Новгород (https://ru.wikipedia.org/wiki/%D0%9D%D0%B8%D0%B6%D0%BD%D0%B8%D0%B9%20%D0%9D%D0%BE%D0%B2%D0%B3%D0%BE%D1%80%D0%BE%D0%B4)
# На ней собрано большое количество красивых домов XIX века.
#
# Источник: Мифология (https://ru.wikipedia.org/wiki/%D0%9C%D0%B8%D1%84%D0%BE%D0%BB%D0%BE%D0%B3%D0%B8%D1%8F)
# С созвездием Пса, Льва, Лебедя, Орла, Скорпиона, Рыб связаны красивые легенды.
#
# Источник: Нуаре, Филипп (https://ru.wikipedia.org/wiki/%D0%9D%D1%83%D0%B0%D1%80%D0%B5%2C%20%D0%A4%D0%B8%D0%BB%D0%B8%D0%BF%D0%BF)
# С удовольствием пел в хоре и выступал в любительских спектаклях учебного театра, где и обнаружил свой очень красивый голос, напевая в хоре Цикады, в детском хоре (La manécanterie des Petits Chanteurs à la croix de bois), с которым он пел в католическом соборе Святого Петра в Риме в Пасху в 1949 году и записал свой первый диск в качестве певца под управлением французского композитора Франсуа Веркана (François Vercken).
#
# Источник: Китай (https://ru.wikipedia.org/wiki/%D0%9A%D0%B8%D1%82%D0%B0%D0%B9)
# Красивые обряды и праздники привлекают зарубежных гостей.
#
# Источник: Бердяев, Николай Александрович (https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%B4%D1%8F%D0%B5%D0%B2%2C%20%D0%9D%D0%B8%D0%BA%D0%BE%D0%BB%D0%B0%D0%B9%20%D0%90%D0%BB%D0%B5%D0%BA%D1%81%D0%B0%D0%BD%D0%B4%D1%80%D0%BE%D0%B2%D0%B8%D1%87)
# Красивая природа меня более привлекала, чем содержание съездов.
#
# Источник: Дания (https://ru.wikipedia.org/wiki/%D0%94%D0%B0%D0%BD%D0%B8%D1%8F)
# Самые красивые здания появляются при Кристиане IV (1588—1648).

# %%
corpus.search('"точка" геометрический NOUN')
# Out:
# Поиск по запросу: "точка" геометрический NOUN
#
#
# РЕЗУЛЬТАТЫ (1/1):
#
# Источник: Материальная точка (https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D1%82%D0%B5%D1%80%D0%B8%D0%B0%D0%BB%D1%8C%D0%BD%D0%B0%D1%8F%20%D1%82%D0%BE%D1%87%D0%BA%D0%B0)
# Материальная точка — геометрическая точка, которой поставлен в соответствие скаляр, называемый массой: , — вектор в евклидовом пространстве, отнесённом к какой-либо декартовой системе координат.

# %%
corpus.search('знать+NOUN')
# Out:
# Поиск по запросу: знать+NOUN
#
#
# РЕЗУЛЬТАТЫ (10/33):
#
# Источник: Берлин (https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D1%80%D0%BB%D0%B8%D0%BD)
# В прошлом Тиргартен был участком леса перед воротами города, который знать города использовала для прогулок на лошадях и охоты.
#
# Источник: 1171 год (https://ru.wikipedia.org/wiki/1171%20%D0%B3%D0%BE%D0%B4)
# Великий князь киевский Глеб Юрьевич отравлен киевской знатью.
#
# Источник: Перестройка (https://ru.wikipedia.org/wiki/%D0%9F%D0%B5%D1%80%D0%B5%D1%81%D1%82%D1%80%D0%BE%D0%B9%D0%BA%D0%B0)
# Эта схема допускала, что те или иные народы могли миновать или не знать ту или иную общественную формацию, но все они так или иначе двигались по заданному пути.
#
# Источник: Хичкок, Альфред (https://ru.wikipedia.org/wiki/%D0%A5%D0%B8%D1%87%D0%BA%D0%BE%D0%BA%2C%20%D0%90%D0%BB%D1%8C%D1%84%D1%80%D0%B5%D0%B4)
# То, что вы всегда хотели знать о Лакане (но боялись спросить у Хичкока) / Под ред.
#
# Источник: Киров (Кировская область) (https://ru.wikipedia.org/wiki/%D0%9A%D0%B8%D1%80%D0%BE%D0%B2%20%28%D0%9A%D0%B8%D1%80%D0%BE%D0%B2%D1%81%D0%BA%D0%B0%D1%8F%20%D0%BE%D0%B1%D0%BB%D0%B0%D1%81%D1%82%D1%8C%29)
# Местная знать была переселена в Подмосковье, а в городе поставлен московский наместник.
#
# Источник: Пиндар (https://ru.wikipedia.org/wiki/%D0%9F%D0%B8%D0%BD%D0%B4%D0%B0%D1%80)
# Принадлежал к знатному фиванскому роду, который восходил к древнейшей знати этого города.
#
# Источник: SMTP (https://ru.wikipedia.org/wiki/SMTP)
# Почтовый клиент должен знать IP-адрес SMTP-сервера, который задаётся как часть конфигурации (обыкновенно в виде DNS-имени).
#
# Источник: Древнеегипетская религия (https://ru.wikipedia.org/wiki/%D0%94%D1%80%D0%B5%D0%B2%D0%BD%D0%B5%D0%B5%D0%B3%D0%B8%D0%BF%D0%B5%D1%82%D1%81%D0%BA%D0%B0%D1%8F%20%D1%80%D0%B5%D0%BB%D0%B8%D0%B3%D0%B8%D1%8F)
# Последним составляющим является место захоронения человека, для фараонов и знати — это пирамиды и гробницы, для простого человека — пески Саккары.
#
# Источник: Лондон (https://ru.wikipedia.org/wiki/%D0%9B%D0%BE%D0%BD%D0%B4%D0%BE%D0%BD)
# В 1216 году во время гражданской войны в город в последний раз вошла иностранная армия французов во главе с принцем, выступивших на стороне знати против короля.
#
# Источник: XII век (https://ru.wikipedia.org/wiki/XII%20%D0%B2%D0%B5%D0%BA)
# Успешно проводил политику централизации государства (увеличил королевский домен примерно в 4 раза, преобразовал в нём управление, ограничил самостоятельность феодальной знати).
#
# Показать больше примеров? (y/n) n
